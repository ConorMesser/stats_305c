# %%
import pandas as pd
import glob
import numpy as np

# %%
files = glob.glob("/Users/laurenwilkes/Downloads/peptides*.csv")

# %%
# 1. Load and combine all files
files = glob.glob("/Users/laurenwilkes/Downloads/activity-against-target-species*.csv")

df = pd.concat(
    [pd.read_csv(f, engine="python", on_bad_lines="skip") for f in files],
    ignore_index=True
)

df.to_csv('MIC_data_original.csv', index=False)
